# %% [markdown]
# # Part 5 | Association Rule Learning

# %%
# Importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Seção 24 | Apriori

# %%
# Importing the dataset

dss24 = pd.read_csv('C:\\Users\\rafae\\Dropbox\\Data_Science\\Cursos\\A_to_Z\\Part 5 - Association Rule Learning\\Section 28 - Apriori\\Market_Basket_Optimisation.csv', header = None)

# %%
dss24.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
transactions = []

for i in range(0, 7501):
    transactions.append([str(dss24.values[i, j]) for j in range(0, 20)])

# %%
from apyori import apriori
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-346717fc90f7> in <module>()
# ----> 1 from apyori import apriori
#
# ModuleNotFoundError: No module named 'apyori'
